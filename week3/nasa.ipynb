# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
api_key = 'C6AxJPX967kzLBmPghyDPbvvmaK7SN6f2BjdMiT8'

# %%
https://api.nasa.gov/DONKI/CMEAnalysis?startDate=2016-09-01&endDate=2016-09-30&mostAccurateOnly=true&speed=500&halfAngle=30&catalog=ALL&api_key=DEMO_KEY

# %%
nasa_base_url = "https://api.nasa.gov/DONKI/CME"

# %%
date1='2016-10-01'
date2='2016-10-30'

# %%
nasa_url = f"{nasa_base_url}?startDate={date1}endDate={date2}&mostAccurateOnly=true&speed=500&halfAngle=30&catalog=ALL&api_key={api_key}"

# %%
response=requests.get(nasa_url)

# %%
response.status_code
# Out:
# 200

# %%
data=response.json()

# %%
data
# Out:
# [{'activityID': '2024-05-23T01:25:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-05-23T01:25Z',
#   'sourceLocation': 'S35E45',
#   'activeRegionNum': None,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/31092/-1',
#   'note': 'Bright lightbulb-shaped CME to the SE with the source a 2023-05-23T00:45Z eruption of an unusually-looking filament stretched longitudinally and centered at S35E45, marked by massive post-eruptive arcades seen in AIA 193.',
#   'submissionTime': '2024-05-24T04:41Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-05-23T09:31Z',
#     'latitude': -35.0,
#     'longitude': -39.0,
#     'halfAngle': 29.0,
#     'speed': 469.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'direct',
#     'measurementTechnique': 'SWPC_CAT',
# ...

# %% [markdown]
# # earth

# %%
https://api.nasa.gov/planetary/earth/assets?lon=-95.33&lat=29.78&date=2018-01-01&&dim=0.10&api_key=DEMO_KEY

# %%
earth_base_url = "https://api.nasa.gov/planetary/earth/assets"

# %%
ion='-80.20'
iat='20.33'
date4='2017-10-01'
api_key='C6AxJPX967kzLBmPghyDPbvvmaK7SN6f2BjdMiT8'

# %%
earth_url = f"{nasa_base_url}?lon=-95.33&lat=29.78&date=2018-01-01&&dim=0.10&api_key={api_key}"

# %%
assets_response = requests.get(earth_url)

# %%
assets_response.status_code
# Out:
# 200

# %%
assets_response.json()
# Out:
# [{'activityID': '2024-05-23T01:25:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-05-23T01:25Z',
#   'sourceLocation': 'S35E45',
#   'activeRegionNum': None,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/31092/-1',
#   'note': 'Bright lightbulb-shaped CME to the SE with the source a 2023-05-23T00:45Z eruption of an unusually-looking filament stretched longitudinally and centered at S35E45, marked by massive post-eruptive arcades seen in AIA 193.',
#   'submissionTime': '2024-05-24T04:41Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-05-23T09:31Z',
#     'latitude': -35.0,
#     'longitude': -39.0,
#     'halfAngle': 29.0,
#     'speed': 469.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'direct',
#     'measurementTechnique': 'SWPC_CAT',
# ...

# %% [markdown]
# # epic

# %%
https://api.nasa.gov/EPIC/api/natural/date/2019-05-30?api_key=DEMO_KEY

# %%
epic_base_url = "https://api.nasa.gov/EPIC/api/natural/date/2019-05-30"

# %%
lon='95.33'
lat='29.78'
api_key='C6AxJPX967kzLBmPghyDPbvvmaK7SN6f2BjdMiT8'
date='2018-01-01'
dim='0.10'

# %%
epic_url = f"{epic_base_url}?api_key={api_key}"

# %%
assert_response=requests.get(epic_url)

# %%
assert_response.status_code
# Out:
# 200

# %%
assert_response.json()
# Out:
# [{'identifier': '20190530011359',
#   'caption': "This image was taken by NASA's EPIC camera onboard the NOAA DSCOVR spacecraft",
#   'image': 'epic_1b_20190530011359',
#   'version': '03',
#   'centroid_coordinates': {'lat': 24.56543, 'lon': 170.683594},
#   'dscovr_j2000_position': {'x': 339005.145834,
#    'y': 1368757.776568,
#    'z': 645861.927788},
#   'lunar_j2000_position': {'x': 381104.35964,
#    'y': 104675.95663,
#    'z': -35701.90868},
#   'sun_j2000_position': {'x': 56531896.481815,
#    'y': 129098775.627199,
#    'z': 55963516.666649},
#   'attitude_quaternions': {'q0': 0.495585,
#    'q1': -0.356553,
#    'q2': -0.694341,
#    'q3': 0.380992},
#   'date': '2019-05-30 01:09:10',
#   'coords': {'centroid_coordinates': {'lat': 24.56543, 'lon': 170.683594},
#    'dscovr_j2000_position': {'x': 339005.145834,
#     'y': 1368757.776568,
#     'z': 645861.927788},
#    'lunar_j2000_position': {'x': 381104.35964,
#     'y': 104675.95663,
#     'z': -35701.90868},
# ...

# %% [markdown]
# # TechTransfer

# %%
https://api.nasa.gov/techtransfer/patent/?engine&api_key=DEMO_KEY

# %%
tech_base_url = "https://api.nasa.gov/techtransfer/patent/"

# %%
tech_url = f"{tech_base_url}?engine&api_key={api_key}"

# %%
tech_response=requests.get(tech_url)

# %%
tech_response.status_code
# Out:
# 200

# %%
tech_response.json()
# Out:
# {'results': [['655dd12a25e61e486e02dbc2',
#    'LEW-TOPS-74',
#    'Annular Ion <span class="highlight">Engine</span>',
# ...
